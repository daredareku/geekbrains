# %% [markdown]
# ## Групповая работа [2]
# Дана функция f(x) = 5x^2 + 10x - 30
# + 1. Определить корни
# + 2. Найти интервалы, на которых функция возрастает
# + 3. Найти интервалы, на которых функция убывает
# + 4. Построить график
# + 5. Вычислить вершину
# + 6. Определить промежутки, на котором f > 0
# + 7. Определить промежутки, на котором f < 0

# %%
pip install sympy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sympy in /home/atitkov/.local/lib/python3.10/site-packages (1.11.1)
# Requirement already satisfied: mpmath>=0.19 in /home/atitkov/.local/lib/python3.10/site-packages (from sympy) (1.2.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/atitkov/.local/lib/python3.10/site-packages (3.6.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/atitkov/.local/lib/python3.10/site-packages (from matplotlib) (1.0.6)
# Requirement already satisfied: fonttools>=4.22.0 in /home/atitkov/.local/lib/python3.10/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/atitkov/.local/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.19 in /home/atitkov/.local/lib/python3.10/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: cycler>=0.10 in /home/atitkov/.local/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/atitkov/.local/lib/python3.10/site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sympy import *
from sympy.plotting import plot as plt
import matplotlib 
init_printing()
plt.set_linestyle='dashed'

#plot.style.use('seaborn')

# %%
#%matplotlib notebook

# %%
x = Symbol('x')

# %%
y = 5*x**2+10*x-30

# %%
plt(y,(x, -20, 30), show=True)
print(y)
# Out:
# 5*x**2 + 10*x - 30

# %%
diff(y)
# Out:
# 10⋅x + 10

# %%
plt(diff(y))

# %%
solve(y)
# Out:
# [-1 + √7, -√7 - 1]

# %%
solve(diff(y))
# Out:
# [-1]

# %%
solve(y > 0)
# Out:
# (-∞ < x ∧ x < -√7 - 1) ∨ (x < ∞ ∧ -1 + √7 < x)

# %%
solve(y <0)
# Out:
# x < -1 + √7 ∧ -√7 - 1 < x

# %%
solve(diff(y)>0)
# Out:
# -1 < x ∧ x < ∞

# %%
solve(diff(y) < 0)
# Out:
# -∞ < x ∧ x < -1

# %%
plt(y,(x,-50, -1))
